# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
import requests
import json
API_KEY = "e6d216bdd30fc098485b192c3e990f6a"   # Replace with your OpenWeatherMap API key
CITY = "Nashik"
URL = f"https://api.openweathermap.org/data/2.5/forecast?q={CITY}&appid={API_KEY}&units=metric"

# Step 3: Fetch data from OpenWeatherMap
response = requests.get(URL)
data = response.json()
data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1762894800,
#    'main': {'temp': 17.69,
#     'feels_like': 16.85,
#     'temp_min': 16.79,
#     'temp_max': 17.69,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 941,
#     'humidity': 51,
#     'temp_kf': 0.9},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 1.26, 'deg': 75, 'gust': 1.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-11 21:00:00'},
#   {'dt': 1762905600,
#    'main': {'temp': 16.6,
#     'feels_like': 15.62,
#     'temp_min': 15.83,
#     'temp_max': 16.6,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 50,
#     'temp_kf': 0.77},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.74, 'deg': 90, 'gust': 1.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-12 00:00:00'},
#   {'dt': 1762916400,
#    'main': {'temp': 19.14,
#     'feels_like': 18.28,
#     'temp_min': 19.14,
#     'temp_max': 19.14,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 2.34, 'deg': 83, 'gust': 3.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-12 03:00:00'},
#   {'dt': 1762927200,
#    'main': {'temp': 24.61,
#     'feels_like': 23.99,
#     'temp_min': 24.61,
#     'temp_max': 24.61,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.29, 'deg': 93, 'gust': 3.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-12 06:00:00'},
#   {'dt': 1762938000,
#    'main': {'temp': 26.66,
#     'feels_like': 26.66,
#     'temp_min': 26.66,
#     'temp_max': 26.66,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 2.24, 'deg': 80, 'gust': 1.98},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-12 09:00:00'},
#   {'dt': 1762948800,
#    'main': {'temp': 23.56,
#     'feels_like': 22.91,
#     'temp_min': 23.56,
#     'temp_max': 23.56,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 1.63, 'deg': 71, 'gust': 1.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-12 12:00:00'},
#   {'dt': 1762959600,
#    'main': {'temp': 19.23,
#     'feels_like': 18.25,
#     'temp_min': 19.23,
#     'temp_max': 19.23,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.41, 'deg': 50, 'gust': 1.49},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-12 15:00:00'},
#   {'dt': 1762970400,
#    'main': {'temp': 17.43,
#     'feels_like': 16.35,
#     'temp_min': 17.43,
#     'temp_max': 17.43,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.37, 'deg': 80, 'gust': 1.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-12 18:00:00'},
#   {'dt': 1762981200,
#    'main': {'temp': 16.51,
#     'feels_like': 15.39,
#     'temp_min': 16.51,
#     'temp_max': 16.51,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.64, 'deg': 82, 'gust': 1.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-12 21:00:00'},
#   {'dt': 1762992000,
#    'main': {'temp': 15.64,
#     'feels_like': 14.49,
#     'temp_min': 15.64,
#     'temp_max': 15.64,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.05, 'deg': 87, 'gust': 2.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-13 00:00:00'},
#   {'dt': 1763002800,
#    'main': {'temp': 19.14,
#     'feels_like': 18.31,
#     'temp_min': 19.14,
#     'temp_max': 19.14,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 944,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.57, 'deg': 87, 'gust': 4.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-13 03:00:00'},
#   {'dt': 1763013600,
#    'main': {'temp': 24.92,
#     'feels_like': 24.3,
#     'temp_min': 24.92,
#     'temp_max': 24.92,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 944,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.51, 'deg': 101, 'gust': 4.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-13 06:00:00'},
#   {'dt': 1763024400,
#    'main': {'temp': 26.9,
#     'feels_like': 26.18,
#     'temp_min': 26.9,
#     'temp_max': 26.9,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 25,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.73, 'deg': 84, 'gust': 2.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-13 09:00:00'},
#   {'dt': 1763035200,
#    'main': {'temp': 23.41,
#     'feels_like': 22.72,
#     'temp_min': 23.41,
#     'temp_max': 23.41,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.18, 'deg': 72, 'gust': 2.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-13 12:00:00'},
#   {'dt': 1763046000,
#    'main': {'temp': 19.24,
#     'feels_like': 18.26,
#     'temp_min': 19.24,
#     'temp_max': 19.24,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.93, 'deg': 70, 'gust': 1.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-13 15:00:00'},
#   {'dt': 1763056800,
#    'main': {'temp': 17.55,
#     'feels_like': 16.61,
#     'temp_min': 17.55,
#     'temp_max': 17.55,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.91, 'deg': 98, 'gust': 1.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-13 18:00:00'},
#   {'dt': 1763067600,
#    'main': {'temp': 16.64,
#     'feels_like': 15.74,
#     'temp_min': 16.64,
#     'temp_max': 16.64,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 941,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.1, 'deg': 93, 'gust': 2.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-13 21:00:00'},
#   {'dt': 1763078400,
#    'main': {'temp': 15.68,
#     'feels_like': 14.9,
#     'temp_min': 15.68,
#     'temp_max': 15.68,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.22, 'deg': 87, 'gust': 2.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-14 00:00:00'},
#   {'dt': 1763089200,
#    'main': {'temp': 19.08,
#     'feels_like': 18.53,
#     'temp_min': 19.08,
#     'temp_max': 19.08,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.89, 'deg': 96, 'gust': 5.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-14 03:00:00'},
#   {'dt': 1763100000,
#    'main': {'temp': 24.97,
#     'feels_like': 24.54,
#     'temp_min': 24.97,
#     'temp_max': 24.97,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 943,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.82, 'deg': 109, 'gust': 4.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-14 06:00:00'},
#   {'dt': 1763110800,
#    'main': {'temp': 26.97,
#     'feels_like': 26.44,
#     'temp_min': 26.97,
#     'temp_max': 26.97,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 940,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.11, 'deg': 103, 'gust': 2.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-14 09:00:00'},
#   {'dt': 1763121600,
#    'main': {'temp': 23.73,
#     'feels_like': 23.23,
#     'temp_min': 23.73,
#     'temp_max': 23.73,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.08, 'deg': 95, 'gust': 2.13},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-14 12:00:00'},
#   {'dt': 1763132400,
#    'main': {'temp': 20.3,
#     'feels_like': 19.59,
#     'temp_min': 20.3,
#     'temp_max': 20.3,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.75, 'deg': 95, 'gust': 1.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-14 15:00:00'},
#   {'dt': 1763143200,
#    'main': {'temp': 18.23,
#     'feels_like': 17.36,
#     'temp_min': 18.23,
#     'temp_max': 18.23,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.18, 'deg': 73, 'gust': 2.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-14 18:00:00'},
#   {'dt': 1763154000,
#    'main': {'temp': 16.77,
#     'feels_like': 15.96,
#     'temp_min': 16.77,
#     'temp_max': 16.77,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 941,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.24, 'deg': 83, 'gust': 2.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-14 21:00:00'},
#   {'dt': 1763164800,
#    'main': {'temp': 15.81,
#     'feels_like': 15.07,
#     'temp_min': 15.81,
#     'temp_max': 15.81,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.11, 'deg': 84, 'gust': 2.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-15 00:00:00'},
#   {'dt': 1763175600,
#    'main': {'temp': 19.11,
#     'feels_like': 18.49,
#     'temp_min': 19.11,
#     'temp_max': 19.11,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.69, 'deg': 88, 'gust': 4.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-15 03:00:00'},
#   {'dt': 1763186400,
#    'main': {'temp': 25.2,
#     'feels_like': 24.72,
#     'temp_min': 25.2,
#     'temp_max': 25.2,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 944,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.2, 'deg': 107, 'gust': 3.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-15 06:00:00'},
#   {'dt': 1763197200,
#    'main': {'temp': 26.99,
#     'feels_like': 26.38,
#     'temp_min': 26.99,
#     'temp_max': 26.99,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.9, 'deg': 102, 'gust': 2.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-15 09:00:00'},
#   {'dt': 1763208000,
#    'main': {'temp': 23.75,
#     'feels_like': 23.2,
#     'temp_min': 23.75,
#     'temp_max': 23.75,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.09, 'deg': 84, 'gust': 2.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-15 12:00:00'},
#   {'dt': 1763218800,
#    'main': {'temp': 20.53,
#     'feels_like': 19.76,
#     'temp_min': 20.53,
#     'temp_max': 20.53,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 943,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.71, 'deg': 124, 'gust': 1.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-15 15:00:00'},
#   {'dt': 1763229600,
#    'main': {'temp': 18.56,
#     'feels_like': 17.75,
#     'temp_min': 18.56,
#     'temp_max': 18.56,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.04, 'deg': 69, 'gust': 2.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-15 18:00:00'},
#   {'dt': 1763240400,
#    'main': {'temp': 16.89,
#     'feels_like': 16.07,
#     'temp_min': 16.89,
#     'temp_max': 16.89,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.25, 'deg': 80, 'gust': 2.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-15 21:00:00'},
#   {'dt': 1763251200,
#    'main': {'temp': 15.68,
#     'feels_like': 14.79,
#     'temp_min': 15.68,
#     'temp_max': 15.68,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.16, 'deg': 77, 'gust': 2.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-16 00:00:00'},
#   {'dt': 1763262000,
#    'main': {'temp': 18.92,
#     'feels_like': 18.17,
#     'temp_min': 18.92,
#     'temp_max': 18.92,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 945,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.04, 'deg': 98, 'gust': 5.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-16 03:00:00'},
#   {'dt': 1763272800,
#    'main': {'temp': 24.85,
#     'feels_like': 24.33,
#     'temp_min': 24.85,
#     'temp_max': 24.85,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 945,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.99, 'deg': 106, 'gust': 5.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-16 06:00:00'},
#   {'dt': 1763283600,
#    'main': {'temp': 26.68,
#     'feels_like': 26.22,
#     'temp_min': 26.68,
#     'temp_max': 26.68,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 942,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.39, 'deg': 96, 'gust': 3.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-16 09:00:00'},
#   {'dt': 1763294400,
#    'main': {'temp': 23.56,
#     'feels_like': 23.02,
#     'temp_min': 23.56,
#     'temp_max': 23.56,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 1.83, 'deg': 103, 'gust': 1.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-16 12:00:00'},
#   {'dt': 1763305200,
#    'main': {'temp': 19.8,
#     'feels_like': 19.01,
#     'temp_min': 19.8,
#     'temp_max': 19.8,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 2, 'deg': 77, 'gust': 2.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-16 15:00:00'},
#   {'dt': 1763316000,
#    'main': {'temp': 17.78,
#     'feels_like': 16.89,
#     'temp_min': 17.78,
#     'temp_max': 17.78,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.38, 'deg': 96, 'gust': 2.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-11-16 18:00:00'}],
#  'city': {'id': 1261731,
#   'name': 'Nashik',
#   'coord': {'lat': 19.9833, 'lon': 73.8},
#   'country': 'IN',
#   'population': 1289497,
#   'timezone': 19800,
#   'sunrise': 1762823480,
#   'sunset': 1762863984}}

# %%
weather_list = data["list"]

weather_data = []
for item in weather_list:
    dt = datetime.fromtimestamp(item["dt"])
    temp = item["main"]["temp"]
    temp_min = item["main"]["temp_min"]
    temp_max = item["main"]["temp_max"]
    humidity = item["main"]["humidity"]
    wind_speed = item["wind"]["speed"]
# 28 2025-11-15 14:30:00  26.99     26.99     26.99        29        2.90
# 29 2025-11-15 17:30:00  23.75     23.75     23.75        39        2.09
# 30 2025-11-15 20:30:00  20.53     20.53     20.53        43        1.71
# 31 2025-11-15 23:30:00  18.56     18.56     18.56        49        2.04
# 32 2025-11-16 02:30:00  16.89     16.89     16.89        55        2.25
# 33 2025-11-16 05:30:00  15.68     15.68     15.68        57        2.16
# 34 2025-11-16 08:30:00  18.92     18.92     18.92        50        3.04
# 35 2025-11-16 11:30:00  24.85     24.85     24.85        36        4.99
# 36 2025-11-16 14:30:00  26.68     26.68     26.68        30        3.39
# 37 2025-11-16 17:30:00  23.56     23.56     23.56        40        1.83
# 38 2025-11-16 20:30:00  19.80     19.80     19.80        45        2.00
# 39 2025-11-16 23:30:00  17.78     17.78     17.78        49        2.38
#
#    Description
# 0    clear sky
# 1    clear sky
# 2    clear sky
# 3    clear sky
# 4    clear sky
# 5    clear sky
# 6    clear sky
# 7    clear sky
# 8    clear sky
# 9    clear sky
# 10   clear sky
# 11   clear sky
# 12   clear sky
# 13   clear sky
# 14   clear sky
# 15   clear sky
# 16   clear sky
# 17   clear sky
# 18   clear sky
# 19   clear sky
# 20   clear sky
# 21   clear sky
# 22   clear sky
# 23   clear sky
# 24   clear sky
# 25   clear sky
# 26   clear sky
# 27   clear sky
# 28   clear sky
# 29   clear sky
# 30   clear sky
# 31   clear sky
# 32   clear sky
# 33   clear sky
# 34   clear sky
# 35   clear sky
# 36   clear sky
# 37   clear sky
# 38   clear sky
# 39   clear sky

# %%
df.shape
# Out:
# (40, 7)

# %%
print("Humidity Range:", df["Humidity"].min(), "to", df["Humidity"].max())
# Out:
# Humidity Range: 25 to 62

# %%
print("Temperature Range:", df["Temp"].min(), "to", df["Temp"].max())
# Out:
# Temperature Range: 15.64 to 26.99

# %%
df.describe()
# Out:
#                   DateTime       Temp  Temp_Min   Temp_Max   Humidity  \
# count                   40  40.000000  40.00000  40.000000  40.000000
# mean   2025-11-14 13:00:00  20.617750  20.57600  20.617750  43.725000
# min    2025-11-12 02:30:00  15.640000  15.64000  15.640000  25.000000
# 25%    2025-11-13 07:45:00  17.520000  17.29500  17.520000  36.000000
# 50%    2025-11-14 13:00:00  19.185000  19.18500  19.185000  45.000000
# 75%    2025-11-15 18:15:00  23.965000  23.96500  23.965000  50.000000
# max    2025-11-16 23:30:00  26.990000  26.99000  26.990000  62.000000
# std                    NaN   3.814299   3.85705   3.814299   9.478687
#
#        Wind_Speed
# count    40.00000
# mean      2.44925
# min       1.26000
# 25%       1.92500
# 50%       2.18000
# 75%       2.77000
# max       4.99000
# std       0.89497

# %%
plt.plot(df["DateTime"], df["Temp"], marker='o')
plt.title("Temperature Change Over Time")
plt.xlabel("Date/Time"); plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.bar(df["DateTime"], df["Wind_Speed"])
plt.title("Wind Speed Variation Over Time")
plt.xlabel("Date/Time"); plt.ylabel("Wind Speed (m/s)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=df, x="Humidity", y="Temp")
plt.title("Temperature vs Humidity")
plt.xlabel("Humidity (%)"); plt.ylabel("Temperature (°C)")
plt.show()

# %%
sns.heatmap(df[["Temp","Humidity","Wind_Speed"]].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation
# 2    clear sky  2025-11-12  November
# 3    clear sky  2025-11-12  November
# 4    clear sky  2025-11-12  November
# 5    clear sky  2025-11-12  November
# 6    clear sky  2025-11-12  November
# 7    clear sky  2025-11-12  November
# 8    clear sky  2025-11-13  November
# 9    clear sky  2025-11-13  November
# 10   clear sky  2025-11-13  November
# 11   clear sky  2025-11-13  November
# 12   clear sky  2025-11-13  November
# 13   clear sky  2025-11-13  November
# 14   clear sky  2025-11-13  November
# 15   clear sky  2025-11-13  November
# 16   clear sky  2025-11-14  November
# 17   clear sky  2025-11-14  November
# 18   clear sky  2025-11-14  November
# 19   clear sky  2025-11-14  November
# 20   clear sky  2025-11-14  November
# 21   clear sky  2025-11-14  November
# 22   clear sky  2025-11-14  November
# 23   clear sky  2025-11-14  November
# 24   clear sky  2025-11-15  November
# 25   clear sky  2025-11-15  November
# 26   clear sky  2025-11-15  November
# 27   clear sky  2025-11-15  November
# 28   clear sky  2025-11-15  November
# 29   clear sky  2025-11-15  November
# 30   clear sky  2025-11-15  November
# 31   clear sky  2025-11-15  November
# 32   clear sky  2025-11-16  November
# 33   clear sky  2025-11-16  November
# 34   clear sky  2025-11-16  November
# 35   clear sky  2025-11-16  November
# 36   clear sky  2025-11-16  November
# 37   clear sky  2025-11-16  November
# 38   clear sky  2025-11-16  November
# 39   clear sky  2025-11-16  November

# %%
daily_summary = df.groupby("Date").agg({
    "Temp": "mean",
    "Humidity": "mean",
    "Wind_Speed": "mean"
}).reset_index()

print(" Daily Weather Summary:")
daily_summary.head()
# Out:
#  Daily Weather Summary:
#          Date      Temp  Humidity  Wind_Speed
# 0  2025-11-12  20.61500    40.625     1.91000
# 1  2025-11-13  20.41375    39.750     2.44000
# 2  2025-11-14  20.70000    47.000     2.64375
# 3  2025-11-15  20.84000    46.000     2.49750
# 4  2025-11-16  20.52000    45.250     2.75500

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\lenovo\anaconda3\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\lenovo\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->folium) (2025.1.31)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.8.2 folium-0.20.0

# %%
import folium, requests, pandas as pd
from folium.plugins import HeatMap

# %%
API_KEY = "e6d216bdd30fc098485b192c3e990f6a"
cities = ["Nashik","Mumbai","Pune"]

rows = []
for c in cities:
    r = requests.get("https://api.openweathermap.org/data/2.5/weather",
                     params={"q": c, "appid": API_KEY, "units":"metric"}).json()
    if r.get("cod") == 200:
        rows.append({"city": c,
                     "lat": r["coord"]["lat"],
                     "lon": r["coord"]["lon"],
                     "temp": r["main"]["temp"],
                     "humidity": r["main"]["humidity"],
                     "wind": r["wind"]["speed"]})
df_map = pd.DataFrame(rows); df_map
# Out:
#      city      lat      lon   temp  humidity  wind
# 0  Nashik  19.9833  73.8000  18.14        52  0.81
# 1  Mumbai  19.0144  72.8479  25.99        57  2.57
# 2    Pune  18.5196  73.8553  21.16        75  0.77

# %%
m = folium.Map(location=[19.99,73.79], zoom_start=6)
for _, x in df_map.iterrows():
    folium.CircleMarker(
        location=[x.lat, x.lon],
        radius=8,
        popup=f"{x.city}: {x.temp}°C | Hum {x.humidity}% | Wind {x.wind} m/s",
        tooltip=x.city,
        fill=True
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef3be956e0ccc03aefab2725410227d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef3be956e0ccc03aefab2725410227d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef3be956e0ccc03aefab2725410227d3 = L.map(
#                 &quot;map_ef3be956e0ccc03aefab2725410227d3&quot;,
#                 {
#                     center: [19.99, 73.79],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88d044ce9a19a87d16e6bbb2271410a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88d044ce9a19a87d16e6bbb2271410a6.addTo(map_ef3be956e0ccc03aefab2725410227d3);
#
#
#             var circle_marker_f1e3f86d2f2f220e05a1b28a96e86976 = L.circleMarker(
#                 [19.9833, 73.8],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ef3be956e0ccc03aefab2725410227d3);
#
#
#         var popup_91fe14a57cf873f5027da2ef19d01bd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28d18ca023897335c4c1129c916cff8e = $(`&lt;div id=&quot;html_28d18ca023897335c4c1129c916cff8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nashik: 18.14°C | Hum 52% | Wind 0.81 m/s&lt;/div&gt;`)[0];
#                 popup_91fe14a57cf873f5027da2ef19d01bd1.setContent(html_28d18ca023897335c4c1129c916cff8e);
#
#
#
#         circle_marker_f1e3f86d2f2f220e05a1b28a96e86976.bindPopup(popup_91fe14a57cf873f5027da2ef19d01bd1)
#         ;
#
#
#
#
#             circle_marker_f1e3f86d2f2f220e05a1b28a96e86976.bindTooltip(
#                 `&lt;div&gt;
#                      Nashik
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_4fbd68ee0284deb92249abe1cf35583d = L.circleMarker(
#                 [19.0144, 72.8479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ef3be956e0ccc03aefab2725410227d3);
#
#
#         var popup_54ccfd51a8508837a6f8c1ce4964319f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c54273b8fa0037275b61a6585929736 = $(`&lt;div id=&quot;html_2c54273b8fa0037275b61a6585929736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mumbai: 25.99°C | Hum 57% | Wind 2.57 m/s&lt;/div&gt;`)[0];
#                 popup_54ccfd51a8508837a6f8c1ce4964319f.setContent(html_2c54273b8fa0037275b61a6585929736);
#
#
#
#         circle_marker_4fbd68ee0284deb92249abe1cf35583d.bindPopup(popup_54ccfd51a8508837a6f8c1ce4964319f)
#         ;
#
#
#
#
#             circle_marker_4fbd68ee0284deb92249abe1cf35583d.bindTooltip(
#                 `&lt;div&gt;
#                      Mumbai
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a0285efe32ab14683c95f1f8a251a853 = L.circleMarker(
#                 [18.5196, 73.8553],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ef3be956e0ccc03aefab2725410227d3);
#
#
#         var popup_61a157b5bb0231b0201926e61e0c9b77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var htm

# %%
m2 = folium.Map(location=[19.99,73.79], zoom_start=6)
HeatMap(df_map[["lat","lon","temp"]].values.tolist(), radius=25).add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f354f21049f575ff807b753a6c37d514 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f354f21049f575ff807b753a6c37d514&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f354f21049f575ff807b753a6c37d514 = L.map(
#                 &quot;map_f354f21049f575ff807b753a6c37d514&quot;,
#                 {
#                     center: [19.99, 73.79],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b4f011786f053102de52d858d8b8e6b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b4f011786f053102de52d858d8b8e6b.addTo(map_f354f21049f575ff807b753a6c37d514);
#
#
#             var heat_map_616fbefa6add2e0440ca74e6c521a083 = L.heatLayer(
#                 [[19.9833, 73.8, 18.14], [19.0144, 72.8479, 25.99], [18.5196, 73.8553, 21.16]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_616fbefa6add2e0440ca74e6c521a083.addTo(map_f354f21049f575ff807b753a6c37d514);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sns.heatmap(df[["Temp","Humidity","Wind_Speed"]].corr(), annot=True, cmap="coolwarm")
plt.title("Weather Data Correlation Heatmap")
plt.show()

# %%
m.save("maharashtra_weather_markers.html")
m2.save("maharashtra_weather_heatmap.html")
print("Saved HTML files.")
# Out:
# Saved HTML files.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime


import requests
import json
API_KEY = "e6d216bdd30fc098485b192c3e990f6a"   # Replace with your OpenWeatherMap API key
CITY = "Nashik"
URL = f"https://api.openweathermap.org/data/2.5/forecast?q={CITY}&appid={API_KEY}&units=metric"

# Step 3: Fetch data from OpenWeatherMap
response = requests.get(URL)
data = response.json()
data


weather_list = data["list"]
weather_data = []
for item in weather_list:
    dt = datetime.fromtimestamp(item["dt"])
    temp = item["main"]["temp"]
    temp_min = item["main"]["temp_min"]
    temp_max = item["main"]["temp_max"]
    humidity = item["main"]["humidity"]
    wind_speed = item["wind"]["speed"]
    description = item["weather"][0]["description"]

    weather_data.append([dt, temp, temp_min, temp_max, humidity, wind_speed, description])


df = pd.DataFrame(weather_data, columns=["DateTime", "Temp", "Temp_Min", "Temp_Max", "Humidity", "Wind_Speed", "Description"])
df

df.info()
df.isnull().sum()
df.shape
df = df.drop_duplicates()

df.shape

print("Humidity Range:", df["Humidity"].min(), "to", df["Humidity"].max())
print("Temperature Range:", df["Temp"].min(), "to", df["Temp"].max())
df.describe()

plt.plot(df["DateTime"], df["Temp"], marker='o')
plt.title("Temperature Change Over Time")
plt.xlabel("Date/Time"); plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


plt.bar(df["DateTime"], df["Wind_Speed"])
plt.title("Wind Speed Variation Over Time")
plt.xlabel("Date/Time"); plt.ylabel("Wind Speed (m/s)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


sns.scatterplot(data=df, x="Humidity", y="Temp")
plt.title("Temperature vs Humidity")
plt.xlabel("Humidity (%)"); plt.ylabel("Temperature (°C)")
plt.show()


sns.heatmap(df[["Temp","Humidity","Wind_Speed"]].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Between Weather Factors")
plt.show()


df["Date"] = df["DateTime"].dt.date
df["Month"] = df["DateTime"].dt.month_name()
df


daily_summary = df.groupby("Date").agg({
    "Temp": "mean",
    "Humidity": "mean",
    "Wind_Speed": "mean"
}).reset_index()

print(" Daily Weather Summary:")
daily_summary.head()

# %%
# !pip install folium

import folium, requests, pandas as pd
from folium.plugins import HeatMap

API_KEY = "e6d216bdd30fc098485b192c3e990f6a"
cities = ["Nashik","Mumbai","Pune"]

rows = []
for c in cities:
    r = requests.get("https://api.openweathermap.org/data/2.5/weather",
                     params={"q": c, "appid": API_KEY, "units":"metric"}).json()
    if r.get("cod") == 200:
        rows.append({"city": c,
                     "lat": r["coord"]["lat"],
                     "lon": r["coord"]["lon"],
                     "temp": r["main"]["temp"],
                     "humidity": r["main"]["humidity"],
                     "wind": r["wind"]["speed"]})
df_map = pd.DataFrame(rows); df_map



m = folium.Map(location=[19.99,73.79], zoom_start=6)
for _, x in df_map.iterrows():
    folium.CircleMarker(
        location=[x.lat, x.lon],
        radius=8,
        popup=f"{x.city}: {x.temp}°C | Hum {x.humidity}% | Wind {x.wind} m/s",
        tooltip=x.city,
        fill=True
    ).add_to(m)
m


m2 = folium.Map(location=[19.99,73.79], zoom_start=6)
HeatMap(df_map[["lat","lon","temp"]].values.tolist(), radius=25).add_to(m2)
m2


sns.heatmap(df[["Temp","Humidity","Wind_Speed"]].corr(), annot=True, cmap="coolwarm")
plt.title("Weather Data Correlation Heatmap")
plt.show()
